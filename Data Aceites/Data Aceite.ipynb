# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

file = os.path.join('C:/Users/eamo8/Desktop/Notebook para repositorio/Data Aceites', 'DataAceites.csv')
df1 = pd.read_csv(file, header=0)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1


df1 = df1
s = df1['Fierro']
df1['Fierro'] = pd.to_numeric(s, errors='coerce')

s = df1['Cromo']
df1['Cromo'] = pd.to_numeric(s, errors='coerce')

s = df1['Aluminio']
df1['Aluminio'] = pd.to_numeric(s, errors='coerce')

s = df1['Cobre']
df1['Cobre'] = pd.to_numeric(s, errors='coerce')

s = df1['Plomo']
df1['Plomo'] = pd.to_numeric(s, errors='coerce')

s = df1['Nickel']
df1['Nickel'] = pd.to_numeric(s, errors='coerce')

s = df1['Plata']
df1['Plata'] = pd.to_numeric(s, errors='coerce')

s = df1['Estano']
df1['Estano'] = pd.to_numeric(s, errors='coerce')

s = df1['Titanio']
df1['Titanio'] = pd.to_numeric(s, errors='coerce')

s = df1['Vanadio']
df1['Vanadio'] = pd.to_numeric(s, errors='coerce')

s = df1['Cadmio']
df1['Cadmio'] = pd.to_numeric(s, errors='coerce')

s = df1['Manganeso']
df1['Manganeso'] = pd.to_numeric(s, errors='coerce')

s = df1['Sodio']
df1['Sodio'] = pd.to_numeric(s, errors='coerce')

s = df1['Potasio']
df1['Potasio'] = pd.to_numeric(s, errors='coerce')

s = df1['Silicio']
df1['Silicio'] = pd.to_numeric(s, errors='coerce')

s = df1['Zinc']
df1['Zinc'] = pd.to_numeric(s, errors='coerce')

s = df1['Bario']
df1['Bario'] = pd.to_numeric(s, errors='coerce')

s = df1['Boro']
df1['Boro'] = pd.to_numeric(s, errors='coerce')

s = df1['Calcio']
df1['Calcio'] = pd.to_numeric(s, errors='coerce')

s = df1['Molibdeno']
df1['Molibdeno'] = pd.to_numeric(s, errors='coerce')

s = df1['Magnesio']
df1['Magnesio'] = pd.to_numeric(s, errors='coerce')

s = df1['Fosforo']
df1['Fosforo'] = pd.to_numeric(s, errors='coerce')

s = df1['v 40']
df1['v 40'] = pd.to_numeric(s, errors='coerce')

s = df1['Contenido agua']
df1['Contenido agua'] = pd.to_numeric(s, errors='coerce')

s = df1['Índice PQ']
df1['Índice PQ'] = pd.to_numeric(s, errors='coerce')

s = df1['Oxidacion']
df1['Oxidacion'] = pd.to_numeric(s, errors='coerce')

s = df1['Partículas > 4um']
df1['Partículas > 4um'] = pd.to_numeric(s, errors='coerce')

s = df1['Partículas > 6um']
df1['Partículas > 6um'] = pd.to_numeric(s, errors='coerce')

s = df1['Partículas > 14um']
df1['Partículas > 14um'] = pd.to_numeric(s, errors='coerce')

s = df1['Family']
df1['Family'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

df1 = df1.rename(columns={
	'Fierro': 'ID',
	'Cromo': 'Fierro',
	'Aluminio': 'Cromo',
	'Cobre': 'Aluminio',
	'Plomo': 'Cobre',
	'Nickel': 'Plomo',
	'Plata': 'Nickel',
	'Estano': 'Plata',
	'Titanio': 'Estano',
	'Vanadio': 'Titanio',
	'Cadmio': 'Vanidio',
	'Manganeso': 'Cadmio',
	'Sodio': 'Magneso',
	'Potasio': 'Sodio',
	'Silicio': 'Potasio',
	'Zinc': 'Silicio',
	'Bario': 'Zinc',
	'Boro': 'Bario',
	'Calcio': 'Boro',
	'Molibdeno': 'Calcio',
	'Magnesio': 'Molibdeno',
	'Fosforo': 'Magnesio',
	'v 40': 'Fosforo',
	'Contenido agua': 'V 40',
	'Índice PQ': 'Contenido agua',
	'Oxidacion': 'Índice PQ',
	'Partículas > 4um': 'Oxidacion',
	'Partículas > 6um': 'Partículas > 4um',
	'Partículas > 14um': 'Partículas > 6um',
	'Family': 'Partículas > 14um',
	'Estado': 'Familia',
	'Diagnostic': 'Estado',
	'Comentario': 'Estado de salud',
	'Recomendacion': 'Comentario',
	'Unnamed: 34': 'Recomendación',
})
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

df1 = df1.drop([
	'ID',
	'Recomendación',
	'Comentario',
	'Estado',
], axis='columns')
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

df1 = df1
cond = ((df1['Estado de salud'].eq('Normal')))
df1['Estado de salud'].mask(cond, other=0, inplace=True)

cond = ((df1['Estado de salud'].eq('Component Wear')))
df1['Estado de salud'].mask(cond, other=1, inplace=True)

cond = ((df1['Estado de salud'].eq('Silica ISO 4406')))
df1['Estado de salud'].mask(cond, other=2, inplace=True)

cond = ((df1['Estado de salud'].eq('Oil Contamination')))
df1['Estado de salud'].mask(cond, other=3, inplace=True)

cond = ((df1['Estado de salud'].eq('Silica and Wear')))
df1['Estado de salud'].mask(cond, other=4, inplace=True)

cond = ((df1['Estado de salud'].eq('Water Contamination')))
df1['Estado de salud'].mask(cond, other=5, inplace=True)

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
# Out:
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_19900\552071793.py:178: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Estado de salud'].mask(cond, other=0, inplace=True)
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_19900\552071793.py:181: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
