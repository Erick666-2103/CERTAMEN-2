# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from functools import partial
from pandas.tseries.frequencies import to_offset

file = os.path.join('/Users/eamo8/Desktop/Notebook para repositorio/Reboiler Raw Data', 'Reboiler_Raw_Data_With_Timestamps.xlsx')
df1 = pd.read_excel(file, header=0)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
df1 = df1.rename(columns={
	'VAL356CI8017-Conductividad': 'Conductividad',
	'VAL356M003-Carga Motor': 'Carga Motor (M003)',
	'VAL356M014-Carga Motor': 'Carga Motor (M014)',
	'VAL356M015-Carga Motor': 'Carga Motor (M015)',
	'VAL356PI8026-Ind.Presión': 'Ind.Presión (PI8026)',
	'VAL356PIC8025-Ind.Presión': 'Ind.Presión (PI8025)',
	'VAL356TI8015-Ind.Temperatura': 'Ind.Temperatura (TI8015)',
	'VAL356TIC8014-Ind.Temperatura': 'Ind.Temperatura (TI8014)',
})
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
df1 = df1.drop([
	'Carga Motor (M003)',
], axis='columns')
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
df1 = df1
s = df1['Fecha']
df1['Fecha'] = pd.to_datetime(s, errors='coerce')

s = df1['Conductividad']
df1['Conductividad'] = pd.to_numeric(s, errors='coerce')

s = df1['Carga Motor (M014)']
df1['Carga Motor (M014)'] = pd.to_numeric(s, errors='coerce')

s = df1['Carga Motor (M015)']
df1['Carga Motor (M015)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Presión (PI8026)']
df1['Ind.Presión (PI8026)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Presión (PI8025)']
df1['Ind.Presión (PI8025)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Temperatura (TI8015)']
df1['Ind.Temperatura (TI8015)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Temperatura (TI8014)']
df1['Ind.Temperatura (TI8014)'] = pd.to_numeric(s, errors='coerce')

s = df1['Estado']
df1['Estado'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
df1 = df1.fillna(method='ffill')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
cond = ((df1['Fecha'].ge(pd.to_datetime('2016-01-01 00:00:00', format='%Y-%m-%d %H:%M:%S', errors='coerce')))
 & (df1['Conductividad'].le(12)))
df1 = df1[cond]
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
df1 = df1
df1.set_index([
	'Fecha',
], inplace=True)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
def roundfunc(t, freq):
	freq = to_offset(freq)
	return pd.Timestamp((t.value // freq.delta.value) * freq.delta.value)

df1 = df1.groupby(partial(roundfunc, freq='120T'))

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
enum = enumerate(df1.groups)
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])
df1 = df1.aggregate('median')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
file = os.path.join('C:/Users/eamo8/Desktop/Notebook para repositorio/Reboiler Raw Data', 'ReboilerDepuradofinal.csv')
df1.to_csv(file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'csv file saved'
# Out:
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_92328\3114673153.py:80: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1 = df1.fillna(method='ffill')
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_92328\3114673153.py:108: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   freq = to_offset(freq)
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_92328\3114673153.py:109: FutureWarning: Minute.delta is deprecated and will be removed in a future version. Use pd.Timedelta(obj) instead
#   return pd.Timestamp((t.value // freq.delta.value) * freq.delta.value)
# 'csv file saved'
