# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

file = os.path.join('C:/Users/eamo8/Desktop/Notebook para repositorio/Chancador', 'Chancador_Raw_Data.csv')
df1 = pd.read_csv(file)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#--------------------------------------
df1 = df1.drop([
	'V. Cero.1',
	'Corriente.4',
	'V. Cero.2',
	'Corriente.2',
	'Corriente.3',
	'V. Cero',
	'Unnamed: 0',
	'Corriente.1',
], axis='columns')
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#----------------------------------------
df1 = df1.rename(columns={
	'Salto Anillo': 'Salto Anillo A',
	'Unnamed: 9': 'Salto Anillo B',
	'Unnamed: 10': 'Salto Anillo C',
	'Unnamed: 11': 'Salto Anillo D',
})
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#------------------------------------------
df1 = df1
s = df1['Tiempo']
df1['Tiempo'] = pd.to_datetime(s, errors='coerce')

s = df1['Corriente']
df1['Corriente'] = pd.to_numeric(s, errors='coerce')

s = df1['T° Retorno']
df1['T° Retorno'] = pd.to_numeric(s, errors='coerce')

s = df1['T° socket Linner']
df1['T° socket Linner'] = pd.to_numeric(s, errors='coerce')

s = df1['T° Excéntrica']
df1['T° Excéntrica'] = pd.to_numeric(s, errors='coerce')

s = df1['T° Alimentación']
df1['T° Alimentación'] = pd.to_numeric(s, errors='coerce')

s = df1['T° Desc. C. Eje']
df1['T° Desc. C. Eje'] = pd.to_numeric(s, errors='coerce')

s = df1['Salto Anillo A']
df1['Salto Anillo A'] = pd.to_numeric(s, errors='coerce')

s = df1['Salto Anillo B']
df1['Salto Anillo B'] = pd.to_numeric(s, errors='coerce')

s = df1['Salto Anillo C']
df1['Salto Anillo C'] = pd.to_numeric(s, errors='coerce')

s = df1['Salto Anillo D']
df1['Salto Anillo D'] = pd.to_numeric(s, errors='coerce')

s = df1['Nivel Taza']
df1['Nivel Taza'] = pd.to_numeric(s, errors='coerce')

s = df1['Setting']
df1['Setting'] = pd.to_numeric(s, errors='coerce')

s = df1['Pesómetro']
df1['Pesómetro'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#-------------------------------------------
df1 = df1.dropna(axis='index')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#-------------------------------------------
df1 = df1
df1.set_index([
	'Tiempo',
], inplace=True)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
#-------------------------------------------
from functools import partial
from pandas.tseries.frequencies import to_offset

def roundfunc(t, freq):
	freq = to_offset(freq)
	return pd.Timestamp((t.value // freq.delta.value) * freq.delta.value)

df20 = df1.groupby(partial(roundfunc, freq='10T'))

attrs = {
	'var': 'df20',
	'type': type(df20).__name__,
}
[attrs]
df20
enum = enumerate(df20.groups)
nextel = next(enum)
nextel[1]
df20.get_group(nextel[1])
nextel = next(enum)
nextel[1]
df20.get_group(nextel[1])
#-------------------------------------------
df20 = df20.aggregate('median')

attrs = {
	'var': 'df20',
	'type': type(df20).__name__,
}
[attrs]
df20
#-------------------------------------------
file = os.path.join('C:/Users/eamo8/Desktop/Notebook para repositorio/Chancador', 'intento 5')
df15.to_csv(file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'csv file saved'
# Out:
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_53048\3700481954.py:12: DtypeWarning: Columns (4,5,6,10,11,16,17,18,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(file)
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_53048\3700481954.py:124: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   freq = to_offset(freq)
# C:\Users\eamo8\AppData\Local\Temp\ipykernel_53048\3700481954.py:125: FutureWarning: Minute.delta is deprecated and will be removed in a future version. Use pd.Timedelta(obj) instead
#   return pd.Timestamp((t.value // freq.delta.value) * freq.delta.value)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# ...
